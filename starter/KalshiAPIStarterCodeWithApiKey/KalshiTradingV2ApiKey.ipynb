# %%
# Welcome to the Kalshi REST v2 Starter Code!

# pypi client: recommended for more advanced programmers
#import kalshi_python

# starter client: recommended for all levels of programming experience (what this client is implemented using)
from KalshiClientsBaseV2ApiKey import ExchangeClient
import time
import json
import uuid

# %%
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend

def load_private_key_from_file(file_path):
    with open(file_path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,  # or provide a password if your key is encrypted
            backend=default_backend()
        )
    return private_key

# %%
# To start off, you need to have created an account at https://kalshi.com (Production) 
# or an account on the Demo https://demo.kalshi.co/

prod_key_id = "" # change these to be your personal credentials
prod_private_key = ""

demo_key_id = "" # change these to be your personal credentials
demo_private_key = load_private_key_from_file('kalshi-key.key')

# for prod
prod_api_base = "https://trading-api.kalshi.com/trade-api/v2"

# for demo
demo_api_base = "https://demo-api.kalshi.co/trade-api/v2"

## if wanting to test in prod:
# exchange_client = ExchangeClient(exchange_api_base=prod_api_base, key_id = prod_key_id, private_key = prod_private_key)

## if wanting to test in demo
exchange_client = ExchangeClient(exchange_api_base = demo_api_base, key_id = demo_key_id, private_key = demo_private_key)

# first we will check on the exchange status to confirm you are properly connected...
print(exchange_client.get_exchange_status())
# Out:
# msg_string 1724881863381GET/trade-api/v2/exchange/status
# signature 
# {'exchange_active': True, 'trading_active': True}

# %%
# You can discover markets through the get_markets endpoint...

# and use query parameters to filter your search!
market_params = {'limit':100,
                    'cursor':None, # passing in the cursor from the previous get_markets call
                    'event_ticker': None,
                    'series_ticker':None,
                    'max_close_ts':None, # pass in unix_ts
                    'min_close_ts':None, # pass in unix_ts
                    'status':None,
                    'tickers':None}

markets_response = exchange_client.get_markets(**market_params)
cursor = markets_response['cursor']

print('keys:', markets_response.keys())
print()
print('number of objects:', len(markets_response['markets'])) # 100 objects!
print()
print('first market in payload:', markets_response['markets'][0])
print()
print('cursor:', cursor)
# Out:
# msg_string 1724881871504GET/trade-api/v2/markets
# signature 
# keys: dict_keys(['markets', 'cursor'])
#
# number of objects: 100
#
# first market in payload: {'ticker': 'NASDAQ100U-24AUG29-T19350.78', 'event_ticker': 'NASDAQ100U-24AUG29', 'market_type': 'binary', 'title': 'Will the Nasdaq-100 be above 19350.78 at the end of Aug 29, 2024?', 'subtitle': '19,350.79 or above', 'yes_sub_title': '19,350.79 or above', 'no_sub_title': '19,350.79 or above', 'open_time': '2024-08-28T20:45:00Z', 'close_time': '2024-08-29T20:00:00Z', 'expected_expiration_time': '2024-08-29T23:00:00Z', 'expiration_time': '2024-09-05T23:00:00Z', 'latest_expiration_time': '2024-09-05T23:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 99, 'yes_ask': 100, 'no_bid': 0, 'no_ask': 1, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 31, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': 'Financials', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 19350.78, 'rules_primary': 'If the Nasdaq 100 index close value for August 29, 2024 is above 19350.78, then the market resolves to Yes.', 'rules_secondary': 'The market will expire at the sooner of the first 7:00 PM ET after the release of the data, or one week after August 29, 2024.\n\nPursuant to the Kalshi Rulebook, the Exchange has modified the Source Agency and Underlying for indices markets. See the rules for more information.'}
#
# cursor: CgwI6L-8tgYQ0LuN0gISGkFVRFVTREgtMjRBVUcyODE3LVQwLjY0Mjc5

# %%
# What are cursors and how do they work?
    
# The Cursor represents a pointer to the next page of records in the pagination.
# So this optional parameter, when filled, should be filled with the cursor string returned in a previous request to this end-point.
# Filling this would basically tell the api to get the next page containing the number of records passed on the limit parameter.
# On the other side not filling it tells the api you want to get the first page for another query.
# The cursor does not store any filters, so if any filter parameters like tickers, max_ts or min_ts were passed in the original query they must be passed again.

# Let's try it in action! Suppose we wanted to get the next 100 market objects...

market_params = {'limit':100,
                    'cursor':cursor, # passing in the cursor from the previous get_markets call
                    'event_ticker': None,
                    'series_ticker': None,
                    'max_close_ts': None, # pass in unix_ts
                    'min_close_ts': None, # pass in unix_ts
                    'status': None,
                    'tickers':None}

markets_response = exchange_client.get_markets(**market_params)
cursor = markets_response['cursor']

print('keys:', markets_response.keys())
print()
print('number of objects:', len(markets_response['markets'])) # 100 objects!
print()
print('first market in market_response payload:', markets_response['markets'][0]) # new markets!
print()
print('new cursor!', cursor)
# Out:
# msg_string 1724881874725GET/trade-api/v2/markets
# signature 
# keys: dict_keys(['markets', 'cursor'])
#
# number of objects: 100
#
# first market in market_response payload: {'ticker': 'AUDUSDH-24AUG2817-T0.64199', 'event_ticker': 'AUDUSDH-24AUG2817', 'market_type': 'binary', 'title': 'AUD/USD price on Aug 28, 2024 at 5pm EDT?', 'subtitle': '0.64200 or above', 'yes_sub_title': '0.64200 or above', 'no_sub_title': '0.64200 or above', 'open_time': '2024-08-28T13:03:02Z', 'close_time': '2024-08-28T21:00:00Z', 'expected_expiration_time': '2024-08-28T21:00:00Z', 'expiration_time': '2024-09-04T21:00:00Z', 'latest_expiration_time': '2024-09-04T21:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'closed', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': 'Financials', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 0.64199, 'rules_primary': 'If the price of the Australian Dollar/US Dollar for August 28, 2024 at 5 PM EDT is above 0.64199, then the market resolves to Yes.', 'rules_secondary': ''}
#
# new cursor! CgsI6L-8tgYQiJ6AfhIaR0JQVVNESC0yNEFVRzI4MTctVDEuMzAxMzk

# %%
# Next, let's look at event level data by passing an event ticker to the get_event endpoint...

event_ticker = markets_response['markets'][5]['event_ticker']
event_params = {'event_ticker': event_ticker}
event_response = exchange_client.get_event(**event_params)

print('keys:', event_response.keys())
print()
print('event object:', event_response['event'])
print()
print('first market in event_response payload:', event_response['markets'][0])
# Out:
# keys: dict_keys(['event', 'markets'])
#
# event object: {'event_ticker': 'GBPUSDH-24AUG2817', 'series_ticker': 'GBPUSDH', 'sub_title': 'Aug 28, 2024 at 5pm EDT', 'title': 'GBP/USD price today at 5pm EDT?', 'mutually_exclusive': False, 'category': 'Financials', 'strike_date': '2024-08-28T21:00:00Z'}
#
# first market in event_response payload: {'ticker': 'GBPUSDH-24AUG2817-T1.29899', 'event_ticker': 'GBPUSDH-24AUG2817', 'market_type': 'binary', 'title': '', 'subtitle': '1.29900 or above', 'yes_sub_title': '1.29900 or above', 'no_sub_title': '1.29900 or above', 'open_time': '2024-08-28T13:03:01Z', 'close_time': '2024-08-28T21:00:00Z', 'expected_expiration_time': '2024-08-28T21:00:00Z', 'expiration_time': '2024-09-04T21:00:00Z', 'latest_expiration_time': '2024-09-04T21:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 1.29899, 'rules_primary': 'If the price of the Pound Sterling/US Dollar for August 28, 2024 at 5 PM EDT is above 1.29899, then the market resolves to Yes.', 'rules_secondary': ''}

# %%
# Next, let's look at series level data by passing a series ticker to the get_series endpoint! 
series_ticker = event_response['event']['series_ticker']
series_params = {'series_ticker': series_ticker}
series_response = exchange_client.get_series(**series_params)

print('keys:', series_response.keys())
print()
print('series object:', series_response['series'])
print()
# Out:
# keys: dict_keys(['series'])
#
# series object: {'ticker': 'GBPUSDH', 'frequency': 'hourly', 'title': 'GBP/USD over/under', 'category': 'Financials', 'tags': [], 'settlement_sources': [{'url': 'https://www.tradingview.com/chart/?symbol=FX_IDC%3AGBPUSD', 'name': 'ICE'}], 'contract_url': 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/GBPUSD.pdf'}

# %%
# Next let's look at the recent market history for a market
ticker = 'NGDP-22-C7.5'

market_history_params = {'ticker': ticker,
                            'limit': 100,
                            'cursor': None,
                            'max_ts': None, # pass in unix_ts
                            'min_ts': round(time.time()-1000000) # passing a recent unix_ts
                                }
market_history_response = exchange_client.get_market_history(**market_history_params)

print('keys:', market_history_response.keys())
print()
print('most recent market history object:', market_history_response['history'][-1])
print()

# and then also look at the most current view of the orderbook
market_history_params = {'ticker':ticker,
                            'depth': 30
                                }
orderbook_response = exchange_client.get_orderbook(**market_history_params)

print('keys:', orderbook_response.keys())
print()
print('orderbook object:', orderbook_response)
print()
# Out:
# keys: dict_keys(['ticker', 'history', 'cursor'])
#
# most recent market history object: {'yes_price': 23, 'yes_bid': 23, 'yes_ask': 87, 'no_bid': 13, 'no_ask': 77, 'volume': 2761, 'open_interest': 1644, 'ts': 1669651310}
#
# keys: dict_keys(['orderbook'])
#
# orderbook object: {'orderbook': {'yes': [[1, 515], [23, 2503]], 'no': [[1, 1146], [2, 152], [3, 38], [6, 300], [7, 38], [12, 62], [13, 154]]}}

# %%
# Now let's suppose we wanted to place a trade on one of these markets... 
# to do so, we would first want to check out available balance...

current_balance = exchange_client.get_balance()
current_balance
# Out:
# {'balance': 44856}

# %%
# Now that you have some balance, you might want to see how your current positions are doing...

positions_params = {'limit': None,
                        'cursor': None,
                        'settlement_status': None,
                        'ticker': None,
                        'event_ticker': None}

current_position = exchange_client.get_positions(**positions_params)
current_position
# Out:
# {'cursor': '',
#  'market_positions': [{'ticker': 'BTCMAXY-24DEC31-90000',
#    'total_traded': 5100,
#    'position': 100,
#    'market_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 175,
#    'last_updated_ts': '2024-06-03T18:04:41.052476Z'},
#   {'ticker': 'BTCMAXY-24DEC31-80000',
#    'total_traded': 9450,
#    'position': 150,
#    'market_exposure': 9450,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 80,
#    'last_updated_ts': '2024-07-31T20:13:10.833106Z'},
#   {'ticker': 'LLM1-24DEC31-OAI',
#    'total_traded': 1206,
#    'position': 21,
#    'market_exposure': 1206,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 17,
#    'last_updated_ts': '2024-06-20T22:39:35.771596Z'},
#   {'ticker': 'LLM1-24DEC31-A',
#    'total_traded': 1950,
#    'position': 50,
#    'market_exposure': 1950,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 84,
#    'last_updated_ts': '2024-07-29T15:07:29.283082Z'},
#   {'ticker': 'CPICORE-24JUN-T0.1',
#    'total_traded': 5700,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -5700,
#    'resting_orders_count': 0,
#    'fees_paid': 172,
#    'last_updated_ts': '2024-07-11T15:55:33.781078Z'},
#   {'ticker': 'ACPI-24-B3.5',
#    'total_traded': 5100,
#    'position': 100,
#    'market_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 175,
#    'last_updated_ts': '2024-06-21T15:04:57.063233Z'},
#   {'ticker': 'ACPICORE-24-B3.5',
#    'total_traded': 6300,
#    'position': 100,
#    'market_exposure': 6300,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 164,
#    'last_updated_ts': '2024-06-18T21:35:18.921885Z'},
#   {'ticker': 'CREDITCDEF-24-Q1-3.10',
#    'total_traded': 930,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 70,
#    'resting_orders_count': 0,
#    'fees_paid': 5,
#    'last_updated_ts': '2024-05-30T14:04:32.307245Z'},
#   {'ticker': 'NASDAQ100Y-24DEC31-B13750',
#    'total_traded': 1,
#    'position': -1,
#    'market_exposure': 1,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-05-02T19:12:20.488391Z'},
#   {'ticker': 'NASDAQ100Y-24DEC31-T18499.99',
#    'total_traded': 6148,
#    'position': 46,
#    'market_exposure': 1196,
#    'realized_pnl': 48,
#    'resting_orders_count': 0,
#    'fees_paid': 67,
#    'last_updated_ts': '2024-01-18T14:30:37.612778Z'},
#   {'ticker': 'RATECUT-24MAY01',
#    'total_traded': 366,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -366,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-05-02T15:48:13.74241Z'},
#   {'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'total_traded': 25000,
#    'position': -500,
#    'market_exposure': 25000,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-05-01T03:30:39.898419Z'},
#   {'ticker': 'PAYROLLS-24MAR-T225000',
#    'total_traded': 301,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -301,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-04-05T15:06:27.973484Z'},
#   {'ticker': 'RATECUT-24MAR20',
#    'total_traded': 4826,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 3374,
#    'resting_orders_count': 0,
#    'fees_paid': 140,
#    'last_updated_ts': '2024-03-21T16:06:17.372081Z'},
#   {'ticker': 'FED-24MAR-T5.25',
#    'total_traded': 21251,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -20451,
#    'resting_orders_count': 0,
#    'fees_paid': 14,
#    'last_updated_ts': '2024-03-20T18:06:25.271253Z'},
#   {'ticker': 'FED-24MAR-T4.50',
#    'total_traded': 62737,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -62737,
#    'resting_orders_count': 0,
#    'fees_paid': 643,
#    'last_updated_ts': '2024-03-20T18:06:01.281098Z'},
#   {'ticker': 'OSCARASPLAY-24-KOTFM',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-03-11T15:05:16.58094Z'},
#   {'ticker': 'OSCARSUPACTR-24-EB',
#    'total_traded': 1720,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 280,
#    'resting_orders_count': 0,
#    'fees_paid': 17,
#    'last_updated_ts': '2024-03-11T15:01:27.511259Z'},
#   {'ticker': 'CREDITCDEF-23-Q4-2.98',
#    'total_traded': 200,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 300,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-23T21:58:15.795302Z'},
#   {'ticker': 'ARGINFLATIONM-24JAN-T150',
#    'total_traded': 51,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': -51,
#    'resting_orders_count': 0,
#    'fees_paid': 1,
#    'last_updated_ts': '2024-02-20T22:21:29.780899Z'},
#   {'ticker': 'GRAMAOTY-66-M',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'GRAMAOTY-66-TR',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'GRAMAOTY-66-S',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-02-05T16:02:00.832166Z'},
#   {'ticker': 'TERMINALRATE-23DEC31-B5.745',
#    'total_traded': 2358,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 242,
#    'resting_orders_count': 0,
#    'fees_paid': 16,
#    'last_updated_ts': '2024-01-04T15:19:56.879127Z'},
#   {'ticker': 'TERMINALRATE-23DEC31-B6.120',
#    'total_traded': 0,
#    'position': 0,
#    'market_exposure': 0,
#    'realized_pnl': 0,
#    'resting_orders_count': 0,
#    'fees_paid': 0,
#    'last_updated_ts': '2024-01-04T15:19:56.879127Z'}],
#  'event_positions': [{'event_ticker': 'BTCMAXY-24DEC31',
#    'total_cost': 14550,
#    'event_exposure': 14550,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 255},
#   {'event_ticker': 'LLM1-24DEC31',
#    'total_cost': 3156,
#    'event_exposure': 3156,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 101},
#   {'event_ticker': 'CPICORE-24JUN',
#    'total_cost': 5700,
#    'event_exposure': 0,
#    'realized_pnl': -5700,
#    'resting_order_count': 0,
#    'fees_paid': 172},
#   {'event_ticker': 'ACPI-2024',
#    'total_cost': 5100,
#    'event_exposure': 5100,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 175},
#   {'event_ticker': 'ACPICORE-2024',
#    'total_cost': 6300,
#    'event_exposure': 6300,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 164},
#   {'event_ticker': 'CREDITCDEF-24-Q1',
#    'total_cost': 930,
#    'event_exposure': 0,
#    'realized_pnl': 70,
#    'resting_order_count': 0,
#    'fees_paid': 5},
#   {'event_ticker': 'NASDAQ100Y-24DEC31',
#    'total_cost': 6149,
#    'event_exposure': 1197,
#    'realized_pnl': 48,
#    'resting_order_count': 0,
#    'fees_paid': 68},
#   {'event_ticker': 'RATECUT-24MAY01',
#    'total_cost': 366,
#    'event_exposure': 0,
#    'realized_pnl': -366,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'TOPALBUMYEAR-24',
#    'total_cost': 25000,
#    'event_exposure': 25000,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'PAYROLLS-24MAR',
#    'total_cost': 301,
#    'event_exposure': 0,
#    'realized_pnl': -301,
#    'resting_order_count': 0,
#    'fees_paid': 1},
#   {'event_ticker': 'RATECUT-24MAR20',
#    'total_cost': 4826,
#    'event_exposure': 0,
#    'realized_pnl': 3374,
#    'resting_order_count': 0,
#    'fees_paid': 140},
#   {'event_ticker': 'FED-24MAR',
#    'total_cost': 83988,
#    'event_exposure': 0,
#    'realized_pnl': -83188,
#    'resting_order_count': 0,
#    'fees_paid': 657},
#   {'event_ticker': 'OSCARASPLAY-24',
#    'total_cost': 0,
#    'event_exposure': 0,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'OSCARSUPACTR-24',
#    'total_cost': 1720,
#    'event_exposure': 0,
#    'realized_pnl': 280,
#    'resting_order_count': 0,
#    'fees_paid': 17},
#   {'event_ticker': 'CREDITCDEF-23-Q4',
#    'total_cost': 200,
#    'event_exposure': 0,
#    'realized_pnl': 300,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'ARGINFLATIONM-24JAN',
#    'total_cost': 51,
#    'event_exposure': 0,
#    'realized_pnl': -51,
#    'resting_order_count': 0,
#    'fees_paid': 1},
#   {'event_ticker': 'GRAMAOTY-66',
#    'total_cost': 0,
#    'event_exposure': 0,
#    'realized_pnl': 0,
#    'resting_order_count': 0,
#    'fees_paid': 0},
#   {'event_ticker': 'TERMINALRATE-23DEC31',
#    'total_cost': 2358,
#    'event_exposure': 0,
#    'realized_pnl': 242,
#    'resting_order_count': 0,
#    'fees_paid': 16}]}

# %%
# seems like some of your recent orders had been filled. To check on those we use the get_positions endpoint ...

fills_params = {'ticker':None,
                    'order_id':None,
                    'min_ts':None,
                    'max_ts':None,
                    'limit': None,
                    'cursor': None}

fills = exchange_client.get_fills(**fills_params)
fills
# Out:
# {'fills': [{'trade_id': '2a68e347-325f-4801-af09-516bbcd17fb3',
#    'ticker': 'BTCMAXY-24DEC31-80000',
#    'order_id': '149b060c-e263-4e6f-9a7b-97fd468f3900',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': False,
#    'created_time': '2024-07-31T20:13:10.833106Z'},
#   {'trade_id': '0801aca3-6230-4093-a699-a6b22908bd97',
#    'ticker': 'BTCMAXY-24DEC31-80000',
#    'order_id': 'f5d8a8a6-b9ab-46b9-a6d6-88a1b7b16798',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 65,
#    'no_price': 35,
#    'is_taker': True,
#    'created_time': '2024-07-31T17:34:34.116259Z'},
#   {'trade_id': '63f3afbd-b82d-4526-8ae3-4d08c6933329',
#    'ticker': 'LLM1-24DEC31-A',
#    'order_id': '47dc838c-6501-4358-856c-dddd7b1f3d82',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 39,
#    'no_price': 61,
#    'is_taker': True,
#    'created_time': '2024-07-29T15:07:29.283082Z'},
#   {'trade_id': 'f95a179c-7a91-4645-bc47-6ec3f40a848b',
#    'ticker': 'CPICORE-24JUN-T0.1',
#    'order_id': '0460ee64-f6b6-4fe3-9272-f00d315ab552',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 57,
#    'no_price': 43,
#    'is_taker': True,
#    'created_time': '2024-06-25T18:05:36.856041Z'},
#   {'trade_id': 'eb6cdd01-717a-4d63-a0e5-493f46e33971',
#    'ticker': 'ACPI-24-B3.5',
#    'order_id': 'dc105b49-32e0-439d-9e30-ffbe5f2f30f3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 51,
#    'no_price': 49,
#    'is_taker': True,
#    'created_time': '2024-06-21T15:04:57.063233Z'},
#   {'trade_id': '639750b1-bca9-437c-b2d0-5d2474083b99',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.771596Z'},
#   {'trade_id': 'a6ad9562-5281-4c96-b100-a37d6f3def88',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.761949Z'},
#   {'trade_id': 'd2e240b7-11f9-4f85-8d1e-743d82e3a4ce',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.751534Z'},
#   {'trade_id': '99572208-ff64-409a-8151-24a6a25d115f',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.740622Z'},
#   {'trade_id': '2903c8e6-a907-4860-aa31-69e009373a44',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.732118Z'},
#   {'trade_id': '8b577970-da71-45f0-81a6-e0bd8ee4bed4',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.722105Z'},
#   {'trade_id': '6f3be3e5-21c6-424d-a59f-88ed62f9dfec',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.711114Z'},
#   {'trade_id': 'e630a35a-ece2-4d9f-b273-b1f7efd69f0c',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.701864Z'},
#   {'trade_id': '1240d1ac-0028-43db-ae15-7fb47146a7ff',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.691349Z'},
#   {'trade_id': '349b6d2e-c519-4ea4-b99a-0efe774954ff',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.681591Z'},
#   {'trade_id': '1fdfca3f-66b7-418a-8649-ad7c5951a670',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.673959Z'},
#   {'trade_id': 'b5b3b84d-9b3e-4c94-a794-1011ba793050',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': 'b6ef1ef0-dc6e-4a71-b1de-81b78c7a9335',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 59,
#    'no_price': 41,
#    'is_taker': True,
#    'created_time': '2024-06-20T21:20:07.472512Z'},
#   {'trade_id': '86c75ee0-9e11-4830-b052-c274c23f103b',
#    'ticker': 'ACPICORE-24-B3.5',
#    'order_id': 'beb29043-8e55-4f12-8c6a-3c73531b80c4',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 63,
#    'no_price': 37,
#    'is_taker': True,
#    'created_time': '2024-06-18T21:35:18.921885Z'},
#   {'trade_id': 'aea01105-856f-413a-bc19-22d6f143076b',
#    'ticker': 'BTCMAXY-24DEC31-90000',
#    'order_id': 'e288726d-885f-4fd3-bcb5-230efdd1fc3f',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 51,
#    'no_price': 49,
#    'is_taker': True,
#    'created_time': '2024-06-03T18:04:41.052476Z'},
#   {'trade_id': '866bd45a-26cd-4a5a-8565-709413749224',
#    'ticker': 'CREDITCDEF-24-Q1-3.10',
#    'order_id': '6b1d2a7e-024c-4b64-9e26-f4e00649a91d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 93,
#    'no_price': 7,
#    'is_taker': True,
#    'created_time': '2024-05-02T19:12:44.449499Z'},
#   {'trade_id': '5e75bddc-d348-4108-a6f5-cce9849fb1ac',
#    'ticker': 'NASDAQ100Y-24DEC31-B13750',
#    'order_id': '8edb4350-7d5d-4c7e-a1e3-f0cc86a73658',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 99,
#    'no_price': 1,
#    'is_taker': True,
#    'created_time': '2024-05-02T19:12:20.488391Z'},
#   {'trade_id': '491bf593-368b-44d3-93e4-e9ca3856c5e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 318,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-05-01T03:30:39.898419Z'},
#   {'trade_id': '587b8804-cf08-429c-9cd2-33ff9381271d',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.669585Z'},
#   {'trade_id': '44d3fed4-c80a-4e46-be15-9b64de44c792',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.660427Z'},
#   {'trade_id': 'ac704293-f804-4766-8691-9069bcf2019e',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.654989Z'},
#   {'trade_id': 'c97ce740-0945-425c-b8f0-e534da1acae6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.649737Z'},
#   {'trade_id': '191ac1fc-a414-48fa-88ab-67e02937c440',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.64467Z'},
#   {'trade_id': 'a99530a4-c4a8-4966-8fbe-e5e31899f7d8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.632737Z'},
#   {'trade_id': '4010fa85-b5f8-4f34-a7fa-6f62bc54db5f',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.624691Z'},
#   {'trade_id': '96839e37-4813-4b68-a409-eb8117235268',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.613766Z'},
#   {'trade_id': '0e42eac5-8181-4ae7-95f4-3839c25e556c',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.60067Z'},
#   {'trade_id': 'c477f012-daac-46f9-9579-2eeeef44c3a7',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.579292Z'},
#   {'trade_id': 'f8eb6143-6d87-43b0-9517-98e32c9cd968',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.567761Z'},
#   {'trade_id': '2e80bab6-aaf7-452d-b74f-776d1ef32ea8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.560543Z'},
#   {'trade_id': 'b96aedc0-406c-472b-a9e7-e606cff73d58',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.549788Z'},
#   {'trade_id': '0e2daea7-f3ba-4a12-8d7b-ccda45ec51b6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.538126Z'},
#   {'trade_id': 'cf0751b6-4d74-452b-add4-06e81b658c0b',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.528525Z'},
#   {'trade_id': 'f6f67603-a449-489d-a3b3-7e50571df080',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.517946Z'},
#   {'trade_id': 'd7c878f7-195f-405d-a3ba-e76c8ce8a1e5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.509665Z'},
#   {'trade_id': '278aea42-0522-4727-9056-ebcac491807d',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.499476Z'},
#   {'trade_id': '7f9254aa-c700-49a8-a3de-c89128eed843',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.487964Z'},
#   {'trade_id': '06e5af39-bda5-4e4c-9bf5-776f8ab4a527',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.472907Z'},
#   {'trade_id': 'd3924973-6db9-4aed-96c0-a66f91308c26',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.466669Z'},
#   {'trade_id': 'f823000f-be7f-430b-9a49-0d8d32ccc571',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.759736Z'},
#   {'trade_id': '05237fa8-149f-457d-bb50-3e695d6c3e5e',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.747567Z'},
#   {'trade_id': '37e659a4-7fe9-4021-aa31-93638ab46f93',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.741255Z'},
#   {'trade_id': '73f6ecf3-58fc-4ee3-b1b1-c4ab9e9ed837',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.728575Z'},
#   {'trade_id': '9b9a8da3-6f6a-4410-aab7-3080754e33e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.721987Z'},
#   {'trade_id': '35572b00-793f-44d2-923a-5210438a3505',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.709179Z'},
#   {'trade_id': 'a8e1b393-8afa-4694-978d-e094ac9aadb1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.700756Z'},
#   {'trade_id': 'b97fe970-1ae4-4429-86d6-68e767ab1500',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.689828Z'},
#   {'trade_id': '407eea36-8744-407a-bdd9-6fd10a3224e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.679531Z'},
#   {'trade_id': '9480fcaf-81fa-473d-a107-b68d05ea29ae',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.669654Z'},
#   {'trade_id': '6f4afd31-802d-490a-b64a-4c9fb1a9e7b8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.653306Z'},
#   {'trade_id': '1e09a017-82ed-4618-9749-b14d8a5db797',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.639444Z'},
#   {'trade_id': '81468ac7-a779-4898-91b8-99354bb5d45c',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.035275Z'},
#   {'trade_id': '96aea34c-f0d7-4afe-ac0f-7c87c1a87708',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.026432Z'},
#   {'trade_id': '924cc00f-a821-48ce-b135-e407300004a5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.012495Z'},
#   {'trade_id': '727d6b81-4748-4155-bacf-85718016e910',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.00171Z'},
#   {'trade_id': '1cb7b546-5bb2-4666-b6b1-bdd238541bc4',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.992114Z'},
#   {'trade_id': '9e6dc851-c5c1-445e-8bd0-40c00d863ced',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.980487Z'},
#   {'trade_id': 'cf0aa846-4c63-4e7b-93e2-f525967c6f62',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.970687Z'},
#   {'trade_id': 'c9adb0b9-5f31-4ca4-9269-422c5df9c4c6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.96081Z'},
#   {'trade_id': '18041630-bff9-4694-a74e-6f524bc3c833',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.950848Z'},
#   {'trade_id': 'e4131f44-a406-4d25-8210-5cf6b1bf32a8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.940795Z'},
#   {'trade_id': '908d4eba-2eb3-4982-a286-48628d1fc31a',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.932628Z'},
#   {'trade_id': '1b5eccc1-f110-4510-ae87-91a5f69a7e51',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.92026Z'},
#   {'trade_id': '5bc7dc59-6f9f-4457-ba80-4153b8ef9e19',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.149617Z'},
#   {'trade_id': '619aa251-829a-4093-9992-56c8f5299178',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.134568Z'},
#   {'trade_id': '4f02555e-7308-4ead-ad45-fae0eb4c8753',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.123387Z'},
#   {'trade_id': 'f7c00aca-85b0-4e6f-8c4c-e2c193e4186b',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.113312Z'},
#   {'trade_id': '399dc86f-6368-41bb-9ff4-e157acb84da2',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.104226Z'},
#   {'trade_id': '387932a8-16f8-46ff-9e70-19b1b89cde5a',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.087721Z'},
#   {'trade_id': '056d661c-0e2e-4a1b-9fcb-19e7ec2224a4',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.081392Z'},
#   {'trade_id': 'a52dabb1-2de0-483e-b019-ed25fd422f01',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.068817Z'},
#   {'trade_id': '6026844a-ff7a-4282-bb70-a99f25acca88',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.060787Z'},
#   {'trade_id': '0a61c92a-784e-46dd-93b3-fc637fa5d9e1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.049153Z'},
#   {'trade_id': 'b3b3e3c5-bca3-4444-981d-ce25a9ce8c05',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.041227Z'},
#   {'trade_id': '207e2161-f2c7-43e7-9dcb-961ae37fe4d1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.647794Z'},
#   {'trade_id': 'd974ab0b-be17-4b4c-80f4-333e38401f06',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.640518Z'},
#   {'trade_id': '022982d6-a333-4353-a780-1ac78641fa26',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.629795Z'},
#   {'trade_id': '3611f1ef-36f8-4c3c-ad82-6d1544770500',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.617722Z'},
#   {'trade_id': '487cdc15-4207-42e3-abfa-7215833c8187',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.608198Z'},
#   {'trade_id': '19b6e67f-967b-495b-b341-857109180f31',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.593519Z'},
#   {'trade_id': '464e5054-969d-4732-872f-ad4486880617',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.584792Z'},
#   {'trade_id': '5ad07391-5297-4f5b-9fff-c1cbabec95dd',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.573408Z'},
#   {'trade_id': 'f758cce9-9f77-4095-89e7-a7154bdc0620',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.565696Z'},
#   {'trade_id': 'c6208801-9040-4835-8138-7471b9814ab5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.553768Z'},
#   {'trade_id': '053a3fc2-9ba5-4918-a21b-ba6023034430',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.545509Z'},
#   {'trade_id': '24b3ad5d-6025-42df-a085-e235278b18a0',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.821661Z'},
#   {'trade_id': '98e28d76-f659-4a3b-9a57-daf4ab79f2d5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.812239Z'},
#   {'trade_id': '56bbf967-6648-48f1-b583-8dd4d87e66cb',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.803807Z'},
#   {'trade_id': 'f24055d3-7a71-4f74-9cad-8a272c71fdf8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.793098Z'},
#   {'trade_id': 'e7540f24-d8c7-422d-8ae6-f5075947b25f',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.778256Z'},
#   {'trade_id': '0cb04ae8-18db-482f-a009-62844a978d84',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.769849Z'},
#   {'trade_id': 'fc59a139-77b7-4dd1-b692-3af76207eea7',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.75899Z'},
#   {'trade_id': 'c1276011-de6a-4430-afac-5e4be0569feb',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.749662Z'},
#   {'trade_id': '3abba717-b7f0-40b3-ab03-c6bfbf379cfe',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.741762Z'},
#   {'trade_id': '9ad3c37c-643d-4b01-88ec-ab55430ab689',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.73601Z'},
#   {'trade_id': '51802dd7-c538-4662-b2ce-a403c258de89',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.722484Z'}],
#  'cursor': 'EhIKEFGALdfFOEZiss6kA8JY3okaDAiKlKmxBhCg9sDYAg'}

# %%
# you may even want to check on some of your recent positions settled...

settlement_params = {'limit': None,
                        'cursor': None}

settlements = exchange_client.get_portfolio_settlements(**settlement_params)
settlements
# Out:
# {'settlements': []}

# %%
# Now onto placing an order...
# There are many different ways to think about placing orders at Kalshi. 
# The following param examples will walk through some of those

# Limit buy order for 10 units at 30c No on GDPW-22-A3

ticker = 'TESTING-5'

order_params = {'ticker':ticker,
                    'client_order_id':str(uuid.uuid4()),
                    'type':'limit',
                    'action':'buy',
                    'side':'no',
                    'count':10,
                    'yes_price':None, # yes_price = 100 - no_price
                    'no_price':30, # no_price = 100 - yes_price
                    'expiration_ts':None,
                    'sell_position_floor':None,
                    'buy_max_cost':None}

exchange_client.create_order(**order_params)

# EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'limit',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':10,
#                     'yes_price':None, # yes_price = 100 - no_price
#                     'no_price':30, # no_price = 100 - yes_price
#                     'expiration_ts':None,
#                     'sell_position_floor':None,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)


# # Market sell order for 12 units Yes on GDPW-22-A3, without flipping position

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)

# # EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'buy',
#                     'side':'no',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)
# Out:
# {'ticker': 'TESTING-5', 'client_order_id': 'bfbd2cb1-2a37-454a-9276-4700ba64f084', 'side': 'no', 'action': 'buy', 'count': 10, 'type': 'limit', 'no_price': 30}
# msg_string 1724881878733POST/trade-api/v2/portfolio/orders
# signature 
# {'order': {'order_id': 'a83b4604-6ad5-49e0-bf65-d89b175df537',
#   'user_id': 'd6a190b7-31de-4855-9fed-e1fd364dc2cf',
#   'ticker': 'TESTING-5',
#   'status': 'resting',
#   'yes_price': 70,
#   'no_price': 30,
#   'created_time': '2024-08-28T21:51:18.993589Z',
#   'expiration_time': None,
#   'self_trade_prevention_type': '',
#   'action': 'buy',
#   'side': 'no',
#   'type': 'limit',
#   'client_order_id': 'bfbd2cb1-2a37-454a-9276-4700ba64f084',
#   'order_group_id': ''}}
